# %%
### If one wants to use Google colab.
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
### Move to the project's folder, ignore it if you have already used your local server.
# %cd /content/drive/MyDrive/optimization
# Out:
# /content/drive/.shortcut-targets-by-id/17eH4aTZSyS6ri9kyUOtZuiChNhsy-0XI/optimization

# %%
### Install requirements of project
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python3 train_classifier.py --path log --wandb 0 --lr 0.01 --opt SGD --dataset cifar10 --epochs 10

# %%
### Enter your API to transfer logs into your account
import wandb
wandb.login()

# %% [markdown]
# ## **SGD**

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.01 --opt SGD --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230609_204643-22nzozdh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_SGD/lr_0.01_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/22nzozdh
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:17, 20.65it/s]
# Epoch = 1
# Train_loss = 1.4756, Train_acc = 0.4850, Train_grad = 1.5728
# Valid_loss = 1.5227, valid_acc = 0.4782, valid_grad = 1.4979
# Test_loss = 1.5218, Test_acc = 0.4724, Test_grad = 1.4870
# learning rate 0.01
# Total time is 44.27375268936157
# ----------
# 352it [00:14, 23.54it/s]
# Epoch = 2
# ...

# %%
#####A100 GPU !python3 train_classifier.py --path log --wandb 1 --lr 0.1 --opt SGD --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_061726-73h5yycr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_SGD/lr_0.1_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/73h5yycr
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:17, 19.64it/s]
# Epoch = 1
# Train_loss = 1.4428, Train_acc = 0.4712, Train_grad = 0.1952
# Valid_loss = 1.4571, valid_acc = 0.474, valid_grad = 0.2171
# Test_loss = 1.4596, Test_acc = 0.4733, Test_grad = 0.2215
# learning rate 0.1
# Total time is 32.38397216796875
# ----------
# 352it [00:10, 34.99it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.1 --opt SGD --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_161526-lu6zsiqz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_SGD/lr_0.1_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/lu6zsiqz
# Files already downloaded and verified
# Files already downloaded and verified
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.05 --opt SGD --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_164544-v7s9y72b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_SGD/lr_0.05_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/v7s9y72b
# Files already downloaded and verified
# Files already downloaded and verified
# ...

# %%
####A100 !python3 train_classifier.py --path log --wandb 1 --lr 0.05 --opt SGD --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_063840-lyy5l216
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_SGD/lr_0.05_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/lyy5l216
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:12, 28.31it/s]
# Epoch = 1
# Train_loss = 1.4788, Train_acc = 0.4909, Train_grad = 0.4952
# Valid_loss = 1.506, valid_acc = 0.4994, valid_grad = 0.4947
# Test_loss = 1.5004, Test_acc = 0.4886, Test_grad = 0.4878
# learning rate 0.05
# Total time is 26.99854612350464
# ----------
# 352it [00:10, 34.70it/s]
# Epoch = 2
# ...

# %%
###A100 !python3 train_classifier.py --path log --wandb 1 --lr 0.1 --opt SGD --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_065942-klgnjoql
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_SGD/lr_0.1_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/klgnjoql
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:12, 28.49it/s]
# Epoch = 1
# Train_loss = 3.4993, Train_acc = 0.1619, Train_grad = 0.2485
# Valid_loss = 3.5108, valid_acc = 0.1648, valid_grad = 0.2537
# Test_loss = 3.5311, Test_acc = 0.1599, Test_grad = 0.2475
# learning rate 0.1
# Total time is 26.77149796485901
# ----------
# 352it [00:10, 35.07it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.1 --opt SGD --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_171604-yrez3ovb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_SGD/lr_0.1_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/yrez3ovb
# Files already downloaded and verified
# Files already downloaded and verified
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.05 --opt SGD --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_174656-ojz8ra15
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_SGD/lr_0.05_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/ojz8ra15
# Files already downloaded and verified
# Files already downloaded and verified
# ...

# %%
#A100 !python3 train_classifier.py --path log --wandb 1 --lr 0.05 --opt SGD --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_072050-zyjbq3ne
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_SGD/lr_0.05_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/zyjbq3ne
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:12, 28.11it/s]
# Epoch = 1
# Train_loss = 3.3599, Train_acc = 0.1858, Train_grad = 0.3586
# Valid_loss = 3.445, valid_acc = 0.1754, valid_grad = 0.4126
# Test_loss = 3.4258, Test_acc = 0.1771, Test_grad = 0.3632
# learning rate 0.05
# Total time is 27.11147713661194
# ----------
# 352it [00:10, 34.02it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.1 --opt SGD --dataset mnist
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_074600-0bjoyzvf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mnist_SGD/lr_0.1_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/0bjoyzvf
# 422it [00:16, 25.23it/s]
# Epoch = 1
# Train_loss = 0.0754, Train_acc = 0.9779, Train_grad = 0.0414
# Valid_loss = 0.0841, valid_acc = 0.9753, valid_grad = 0.0441
# Test_loss = 0.0715, Test_acc = 0.9784, Test_grad = 0.0464
# learning rate 0.1
# Total time is 31.17349338531494
# ----------
# 422it [00:08, 51.39it/s]
# Epoch = 2
# Train_loss = 0.0618, Train_acc = 0.983, Train_grad = 0.0435
# Valid_loss = 0.0742, valid_acc = 0.9818, valid_grad = 0.0434
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.05 --opt SGD --dataset mnist

# %% [markdown]
# # **ADAM**

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.01 --opt ADAM --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_084342-44ncbmv3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_ADAM/lr_0.01_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/44ncbmv3
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:14, 25.01it/s]
# Epoch = 1
# Train_loss = 1.7377, Train_acc = 0.3865, Train_grad = 0.4502
# Valid_loss = 1.7167, valid_acc = 0.3898, valid_grad = 0.4153
# Test_loss = 1.7387, Test_acc = 0.3913, Test_grad = 0.4664
# learning rate 0.01
# Total time is 38.69497728347778
# ----------
# 352it [00:11, 30.85it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.005 --opt ADAM --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_091400-4iz9k9ok
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_ADAM/lr_0.005_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/4iz9k9ok
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:13, 26.66it/s]
# Epoch = 1
# Train_loss = 1.4056, Train_acc = 0.4962, Train_grad = 0.4378
# Valid_loss = 1.3868, valid_acc = 0.5098, valid_grad = 0.4124
# Test_loss = 1.4049, Test_acc = 0.4923, Test_grad = 0.4263
# learning rate 0.005
# Total time is 35.731345415115356
# ----------
# 352it [00:12, 28.60it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.01 --opt ADAM --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_094345-dajig56j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_ADAM/lr_0.01_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/dajig56j
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:13, 25.17it/s]
# Epoch = 1
# Train_loss = 3.9272, Train_acc = 0.0818, Train_grad = 0.2258
# Valid_loss = 3.9484, valid_acc = 0.0796, valid_grad = 0.2279
# Test_loss = 3.939, Test_acc = 0.0841, Test_grad = 0.2187
# learning rate 0.01
# Total time is 37.68087983131409
# ----------
# 352it [00:12, 28.49it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.005 --opt ADAM --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_101309-52zj0p04
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_ADAM/lr_0.005_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/52zj0p04
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:13, 25.66it/s]
# Epoch = 1
# Train_loss = 3.5444, Train_acc = 0.138, Train_grad = 0.391
# Valid_loss = 3.5898, valid_acc = 0.1286, valid_grad = 0.4233
# Test_loss = 3.5884, Test_acc = 0.1384, Test_grad = 0.3942
# learning rate 0.005
# Total time is 35.75322484970093
# ----------
# 352it [00:12, 28.78it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.01 --opt ADAM --dataset mnist
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_214724-uidgxa72
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mnist_ADAM/lr_0.01_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/uidgxa72
# 422it [00:11, 37.09it/s]
# Epoch = 1
# Train_loss = 0.1141, Train_acc = 0.9701, Train_grad = 0.0596
# Valid_loss = 0.1281, valid_acc = 0.9627, valid_grad = 0.062
# Test_loss = 0.1141, Test_acc = 0.9691, Test_grad = 0.0672
# learning rate 0.01
# Total time is 26.221714735031128
# ----------
# 422it [00:09, 43.04it/s]
# Epoch = 2
# Train_loss = 0.076, Train_acc = 0.9789, Train_grad = 0.0514
# Valid_loss = 0.0848, valid_acc = 0.9768, valid_grad = 0.0558
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.005 --opt ADAM --dataset mnist
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_104229-2oqrn7xw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mnist_ADAM/lr_0.005_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/2oqrn7xw
# 422it [00:11, 37.84it/s]
# Epoch = 1
# Train_loss = 0.0867, Train_acc = 0.9758, Train_grad = 0.0547
# Valid_loss = 0.0992, valid_acc = 0.972, valid_grad = 0.0568
# Test_loss = 0.0906, Test_acc = 0.9729, Test_grad = 0.0613
# learning rate 0.005
# Total time is 25.696202039718628
# ----------
# 422it [00:07, 53.12it/s]
# Epoch = 2
# Train_loss = 0.0396, Train_acc = 0.9881, Train_grad = 0.0393
# Valid_loss = 0.0494, valid_acc = 0.9862, valid_grad = 0.0427
# ...

# %% [markdown]
# # **Sophia**

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.01 --opt Sophia --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_145544-5vcorjgo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_Sophia/lr_0.01_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/5vcorjgo
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:16, 21.86it/s]
# Epoch = 1
# Train_loss = 1.686, Train_acc = 0.3641, Train_grad = 0.0326
# Valid_loss = 1.6965, valid_acc = 0.3546, valid_grad = 0.0343
# Test_loss = 1.6819, Test_acc = 0.3678, Test_grad = 0.0333
# learning rate 0.01
# Total time is 39.187424182891846
# ----------
# 352it [00:14, 24.66it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.005 --opt Sophia --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_152706-th14yz70
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_Sophia/lr_0.005_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/th14yz70
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:15, 22.75it/s]
# Epoch = 1
# Train_loss = 1.8132, Train_acc = 0.3818, Train_grad = 0.1278
# Valid_loss = 1.8149, valid_acc = 0.3792, valid_grad = 0.1258
# Test_loss = 1.8197, Test_acc = 0.3815, Test_grad = 0.1259
# learning rate 0.005
# Total time is 38.35492539405823
# ----------
# 352it [00:13, 25.68it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.01 --opt Sophia --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_155809-micjp6je
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_Sophia/lr_0.01_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/micjp6je
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:16, 21.37it/s]
# Epoch = 1
# Train_loss = 4.3559, Train_acc = 0.0385, Train_grad = 0.1128
# Valid_loss = 4.338, valid_acc = 0.0366, valid_grad = 0.1015
# Test_loss = 4.3634, Test_acc = 0.0347, Test_grad = 0.109
# learning rate 0.01
# Total time is 40.67025423049927
# ----------
# 352it [00:14, 24.54it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.005 --opt Sophia --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_162951-xy9kpevp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_Sophia/lr_0.005_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/xy9kpevp
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:16, 21.61it/s]
# Epoch = 1
# Train_loss = 3.9718, Train_acc = 0.0774, Train_grad = 0.0493
# Valid_loss = 3.9752, valid_acc = 0.078, valid_grad = 0.0531
# Test_loss = 3.9903, Test_acc = 0.0758, Test_grad = 0.0515
# learning rate 0.005
# Total time is 39.06360220909119
# ----------
# 352it [00:14, 24.93it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.01 --opt Sophia --dataset mnist

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.005 --opt Sophia --dataset mnist
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_172237-9sxnnt69
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mnist_Sophia/lr_0.005_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/9sxnnt69
# 422it [00:11, 36.55it/s]
# Epoch = 1
# Train_loss = 0.3984, Train_acc = 0.8921, Train_grad = 0.2014
# Valid_loss = 0.4067, valid_acc = 0.89, valid_grad = 0.1899
# Test_loss = 0.3831, Test_acc = 0.895, Test_grad = 0.2032
# learning rate 0.005
# Total time is 26.05664825439453
# ----------
# 422it [00:10, 41.76it/s]
# Epoch = 2
# Train_loss = 0.4164, Train_acc = 0.8853, Train_grad = 0.1675
# Valid_loss = 0.4134, valid_acc = 0.8847, valid_grad = 0.1607
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.001 --opt Sophia --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_201932-s5n0s3tb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_Sophia/lr_0.001_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/s5n0s3tb
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:15, 22.24it/s]
# Epoch = 1
# Train_loss = 1.6343, Train_acc = 0.4769, Train_grad = 1.0327
# Valid_loss = 1.5741, valid_acc = 0.4742, valid_grad = 1.0972
# Test_loss = 1.5897, Test_acc = 0.4662, Test_grad = 0.9005
# learning rate 0.001
# Total time is 38.43907833099365
# ----------
# 352it [00:13, 25.74it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.001 --opt Sophia --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_205040-ifqidx6m
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_Sophia/lr_0.001_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/ifqidx6m
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:16, 21.52it/s]
# Epoch = 1
# Train_loss = 4.597, Train_acc = 0.1388, Train_grad = 1.2166
# Valid_loss = 4.8199, valid_acc = 0.1414, valid_grad = 2.0561
# Test_loss = 4.7617, Test_acc = 0.1335, Test_grad = 1.3309
# learning rate 0.001
# Total time is 38.859333753585815
# ----------
# 352it [00:13, 25.35it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.001 --opt Sophia --dataset mnist
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_212225-z36wcl5b
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mnist_Sophia/lr_0.001_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/z36wcl5b
# 422it [00:11, 36.11it/s]
# Epoch = 1
# Train_loss = 0.0738, Train_acc = 0.9791, Train_grad = 0.0414
# Valid_loss = 0.0854, valid_acc = 0.9782, valid_grad = 0.048
# Test_loss = 0.078, Test_acc = 0.9785, Test_grad = 0.0461
# learning rate 0.001
# Total time is 26.109245777130127
# ----------
# 422it [00:10, 41.94it/s]
# Epoch = 2
# Train_loss = 0.0591, Train_acc = 0.9837, Train_grad = 0.0483
# Valid_loss = 0.0612, valid_acc = 0.9823, valid_grad = 0.0522
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.0001 --opt Sophia --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230610_220723-u0dkr76k
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_Sophia/lr_0.0001_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/u0dkr76k
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:15, 22.56it/s]
# Epoch = 1
# Train_loss = 1.2629, Train_acc = 0.5419, Train_grad = 2.0632
# Valid_loss = 1.278, valid_acc = 0.537, valid_grad = 2.0738
# Test_loss = 1.3259, Test_acc = 0.5294, Test_grad = 2.158
# learning rate 0.0001
# Total time is 38.84211087226868
# ----------
# 352it [00:13, 25.32it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.0001 --opt Sophia --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_043231-xdbiddig
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_Sophia/lr_0.0001_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/xdbiddig
# Files already downloaded and verified
# Files already downloaded and verified
# 352it [00:15, 22.84it/s]
# Epoch = 1
# Train_loss = 3.2899, Train_acc = 0.2129, Train_grad = 4.2597
# Valid_loss = 3.4273, valid_acc = 0.185, valid_grad = 4.3909
# Test_loss = 3.4109, Test_acc = 0.1967, Test_grad = 4.1326
# learning rate 0.0001
# Total time is 37.74798607826233
# ----------
# 352it [00:14, 24.66it/s]
# Epoch = 2
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.0001 --opt Sophia --dataset mnist

# %% [markdown]
# # **Adahessian**

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.15 --opt adahessian --dataset cifar10
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_140148-bq2x0tay
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar10_adahessian/lr_0.15_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/bq2x0tay
# Files already downloaded and verified
# Files already downloaded and verified
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.15 --opt adahessian --dataset cifar100
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_145656-b4z870nd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run cifar100_adahessian/lr_0.15_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/b4z870nd
# Files already downloaded and verified
# Files already downloaded and verified
# ...

# %%
# !python3 train_classifier.py --path log --wandb 1 --lr 0.15 --opt adahessian --dataset mnist
# Out:
# sssss
# wandb: Currently logged in as: amirm77. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/drive/MyDrive/optimization/wandb/run-20230611_155248-7xwjs3o0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run mnist_adahessian/lr_0.15_momentom_0.9_weightdecay_0.0002
# wandb: ⭐️ View project at https://wandb.ai/amirm77/Second_Order_Method
# wandb: 🚀 View run at https://wandb.ai/amirm77/Second_Order_Method/runs/7xwjs3o0
# ...

# %% [markdown]
# # **Visualization**

# %%
import utils
import os
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
datasets = ['cifar10', 'cifar100', 'mnist']
optimizers = ['SGD', 'ADAM', 'adahessian', 'Sophia']
colors = ['#E87B9F', '#A46750', '#479A5F', '#5BC5DB']
names = ['SGD', 'Adam', 'AdaHessian', 'Sophia']

# %%
def get_generalization_error(logs):
   gen_array = []
   for log in logs:
      gen_array.append(float(log['train_acc']) - float(log['test_acc']))
   return gen_array

# %%
def finding_best_hyper():
  out = dict()
  for d in datasets:
    for opt in optimizers:
      dir = f"log/{d}/{opt}"
      learning_rates = [float(name.split('_')[1]) for name in os.listdir(dir)]
      valid_accs = []
      for lr in learning_rates:
        path = dir + f"/lr_{lr}" + "_momentom_0.9_weightdecay_0.0002/logs.pkl"
        logs = utils.load_logs(path)
        valid_accs.append(logs[-1]['val_acc'])
      best_lr = learning_rates[np.argmax(valid_accs)]
      print(f'The best learning rate for {d}, {opt} is {best_lr}')
      out[d, opt] = best_lr
  return out

# %%
best_lr = finding_best_hyper()
# Out:
# The best learning rate for cifar10, ADAM is 0.005
# The best learning rate for cifar10, SGD is 0.05
# The best learning rate for cifar10, Sophia is 0.001
# The best learning rate for cifar10, adahessian is 0.15
# The best learning rate for cifar100, ADAM is 0.005
# The best learning rate for cifar100, SGD is 0.1
# The best learning rate for cifar100, Sophia is 0.0001
# The best learning rate for cifar100, adahessian is 0.15
# The best learning rate for mnist, ADAM is 0.005
# The best learning rate for mnist, SGD is 0.1
# The best learning rate for mnist, Sophia is 0.0001
# The best learning rate for mnist, adahessian is 0.15

# %%
def plot_gen_error(dataset, best_lr):
    d = dataset
    for num, opt in enumerate(optimizers):
        dir = f"log/{d}/{opt}"
        lr = best_lr[d, opt]
        path = dir + f"/lr_{lr}" + "_momentom_0.9_weightdecay_0.0002/logs.pkl"
        logs = utils.load_logs(path)
        g = get_generalization_error(logs)
        plt.ylabel('Gen. Error')
        plt.xlabel('#epochs')
        if num in [3,2]:
          plt.plot(g, label = names[num], color=colors[num],
                   linewidth=2, linestyle='--')
        else:
          plt.plot(g, label = names[num], color=colors[num],
                   linewidth=2)
        # plt.legend()

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Arial'] + plt.rcParams['font.serif']

# %%
plt.style.use('ggplot')
font = {
        'weight' : 'bold',
        'size'   : 16}
matplotlib.rc('font', **font)
plt.figure(figsize=(6,4))
plot_gen_error(datasets[0], best_lr)
plt.tight_layout()
plt.savefig('gen_error_cifar10', format='pdf')

# %%
plt.figure(figsize=(6,4))
plot_gen_error(datasets[1], best_lr)
plt.tight_layout()
plt.savefig('gen_error_cifar100', format='pdf')

# %%
plt.figure(figsize=(6,4))
plot_gen_error(datasets[2], best_lr)
plt.tight_layout()
plt.savefig('gen_error_mnist', format='pdf')

# %%
def plot_test_acc(dataset, best_lr):
    d = dataset
    for num, opt in enumerate(optimizers):
        dir = f"log/{d}/{opt}"
        lr = best_lr[d, opt]
        path = dir + f"/lr_{lr}" + "_momentom_0.9_weightdecay_0.0002/logs.pkl"
        logs = utils.load_logs(path)
        g = [float(log['test_acc']) for log in logs]
        plt.ylabel('Test Accuracy')
        plt.xlabel('#epochs')
        if num in [3,2]:
          plt.plot(g, label = names[num], color=colors[num],
                   linewidth=2, linestyle='--')
        else:
          plt.plot(g, label = names[num], color=colors[num],
                   linewidth=2)
        plt.legend()

# %%
plt.figure(figsize=(6,4))
plot_test_acc(datasets[0], best_lr)
plt.tight_layout()
plt.savefig('test_acc_cifar10', format='pdf')

# %%
plt.figure(figsize=(6,4))
plot_test_acc(datasets[1], best_lr)
plt.tight_layout()
plt.savefig('test_acc_cifar100', format='pdf')

# %%
plt.figure(figsize=(6,4))
plot_test_acc(datasets[2], best_lr)
plt.tight_layout()
plt.savefig('test_acc_mnist', format='pdf', bbox_inches = "tight")

# %%
def plot_time(dataset, best_lr):
    d = dataset
    for num, opt in enumerate(optimizers):
        dir = f"log/{d}/{opt}"
        lr = best_lr[d, opt]
        path = dir + f"/lr_{lr}" + "_momentom_0.9_weightdecay_0.0002/logs.pkl"
        logs = utils.load_logs(path)
        g = [float(log['time']) for log in logs]
        plt.ylabel('Runtime')
        plt.xlabel('#epochs')
        if num in [3,2]:
          plt.plot(g, label = names[num], color=colors[num],
                   linewidth=2, linestyle='--')
        else:
          plt.plot(g, label = names[num], color=colors[num],
                   linewidth=2)

# %%
plt.figure(figsize=(6,4))
plot_time(datasets[0], best_lr)
plt.tight_layout()
plt.savefig('time_cifar10', format='pdf', bbox_inches = "tight")

# %%
plt.figure(figsize=(6,4))
plot_time(datasets[1], best_lr)
plt.tight_layout()
plt.savefig('time_cifar100', format='pdf', bbox_inches = "tight")

# %%
plt.figure(figsize=(6,4))
plot_time(datasets[2], best_lr)
plt.tight_layout()
plt.savefig('time_mnist', format='pdf', bbox_inches = "tight")
